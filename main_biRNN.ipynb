# %%
import torch
import numpy as np
import pickle
import os
import sys
import matplotlib.pyplot as plt

from model.baseline.bi_rnn import biRNN
from utils.loss import rmse
from utils.F_train_validate import fit, validate
from configs.LSTM_GRU_configs import Configs

# return to main dir
current_directory = os.getcwd()
main_dir = os.path.dirname(current_directory+'/dataloader/')
sys.path.append(main_dir)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'avaiable device: {device}')
# Out:
# avaiable device: cuda

# %%
# random seed
seed = 77
torch.manual_seed(seed)
np.random.seed(seed)

if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
with open('dataloader/save/LSTM_GRU/train_loader.pkl', 'rb') as file:
    train_loader = pickle.load(file)
with open('dataloader/save/LSTM_GRU/val_loader.pkl', 'rb') as file:
    val_loader = pickle.load(file)
print('training and validation dataloaders are loaded!')
# Out:
# training and validation dataloaders are loaded!

# %%
lr = 5e-6
epochs = 30
patience = 5
model_save_dir = os.path.dirname(main_dir) + '/model_save/biRNN.pth'

# %%
configs = Configs()
model = biRNN(configs).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
train_loss, val_loss = fit(model, epochs, train_loader, val_loader,
                           optimizer, rmse, patience=patience,
                           model_save_dir=model_save_dir, device=device)
# Out:
# Epoch No.1 || Training loss: 0.069501 || Validation loss: 0.012044 || Time: 35.471 sec
# Epoch No.2 || Training loss: 0.011862 || Validation loss: 0.006184 || Time: 35.234 sec
# Epoch No.3 || Training loss: 0.00957 || Validation loss: 0.005673 || Time: 35.506 sec
# Epoch No.4 || Training loss: 0.009024 || Validation loss: 0.004395 || Time: 35.151 sec
# Epoch No.5 || Training loss: 0.008866 || Validation loss: 0.003863 || Time: 34.942 sec
# Epoch No.6 || Training loss: 0.008585 || Validation loss: 0.003758 || Time: 35.105 sec
# Epoch No.7 || Training loss: 0.008481 || Validation loss: 0.00432 || Time: 34.966 sec
# Epoch No.8 || Training loss: 0.008279 || Validation loss: 0.003178 || Time: 35.299 sec
# Epoch No.9 || Training loss: 0.008285 || Validation loss: 0.003073 || Time: 34.928 sec
# Epoch No.10 || Training loss: 0.008236 || Validation loss: 0.002674 || Time: 35.04 sec
# Epoch No.11 || Training loss: 0.008205 || Validation loss: 0.002583 || Time: 34.947 sec
# Epoch No.12 || Training loss: 0.008003 || Validation loss: 0.002875 || Time: 35.003 sec
# Epoch No.13 || Training loss: 0.008352 || Validation loss: 0.002707 || Time: 35.221 sec
# Epoch No.14 || Training loss: 0.008092 || Validation loss: 0.002345 || Time: 34.998 sec
# Epoch No.15 || Training loss: 0.008257 || Validation loss: 0.002167 || Time: 35.38 sec
# Epoch No.16 || Training loss: 0.008147 || Validation loss: 0.002343 || Time: 35.173 sec
# Epoch No.17 || Training loss: 0.008096 || Validation loss: 0.001893 || Time: 35.276 sec
# Epoch No.18 || Training loss: 0.008018 || Validation loss: 0.002226 || Time: 35.186 sec
# Epoch No.19 || Training loss: 0.008119 || Validation loss: 0.003612 || Time: 35.253 sec
# Epoch No.20 || Training loss: 0.008205 || Validation loss: 0.005174 || Time: 35.301 sec
# Epoch No.21 || Training loss: 0.008224 || Validation loss: 0.002803 || Time: 34.977 sec
# Epoch No.22 || Training loss: 0.007914 || Validation loss: 0.001593 || Time: 35.262 sec
# Epoch No.23 || Training loss: 0.00795 || Validation loss: 0.002551 || Time: 35.24 sec
# Epoch No.24 || Training loss: 0.007749 || Validation loss: 0.001371 || Time: 35.213 sec
# Epoch No.25 || Training loss: 0.007867 || Validation loss: 0.003773 || Time: 35.228 sec
# Epoch No.26 || Training loss: 0.008026 || Validation loss: 0.001574 || Time: 35.186 sec
# Epoch No.27 || Training loss: 0.00793 || Validation loss: 0.001577 || Time: 35.454 sec
# Epoch No.28 || Training loss: 0.00809 || Validation loss: 0.002737 || Time: 35.044 sec
# Epoch No.29 || Training loss: 0.008055 || Validation loss: 0.002848 || Time: 35.289 sec
# Early stopping at 29 epochs

# %%
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend()

# %%
with open('dataloader/save/LSTM_GRU/US06_test_loader.pkl', 'rb') as file:
    US06_test_loader = pickle.load(file)
with open('dataloader/save/LSTM_GRU/HWFTa_test_loader.pkl', 'rb') as file:
    HWFTa_test_loader = pickle.load(file)
with open('dataloader/save/LSTM_GRU/HWFTb_test_loader.pkl', 'rb') as file:
    HWFTb_test_loader = pickle.load(file)
with open('dataloader/save/LSTM_GRU/eneroc_test_loader.pkl', 'rb') as file:
    eneroc_test_loader = pickle.load(file)
print(f'Test dataloaders are loaded!')
# Out:
# Test dataloaders are loaded!

# %%
# load best model
best_model = biRNN(configs).to(device)
best_model.load_state_dict(torch.load(model_save_dir))
# Out:
# <All keys matched successfully>

# %%
US06_val_loss_epoch, US06_target_log, US06_pred_log = validate(best_model, US06_test_loader, rmse, device=device)

plt.plot(US06_pred_log.reshape(-1).cpu(), label='Predicted label')
plt.plot(US06_target_log.reshape(-1).cpu(), label='True label')
plt.title('US06 Test Result')
plt.xlabel('Samples')
plt.ylabel('SOC (%)')
plt.legend()
print(f'RMSE Loss: {rmse(US06_pred_log, US06_target_log)}')
# Out:
# RMSE Loss: 0.002860883018001914

# %%
HWFTa_val_loss_epoch, HWFTa_target_log, HWFTa_pred_log = validate(best_model, HWFTa_test_loader, rmse, device=device)

plt.plot(HWFTa_pred_log.reshape(-1).cpu(), label='Predicted label')
plt.plot(HWFTa_target_log.reshape(-1).cpu(), label='True label')
plt.title('HWFTa Test Result')
plt.xlabel('Samples')
plt.ylabel('SOC (%)')
plt.legend()
print(f'RMSE Loss: {rmse(HWFTa_pred_log, HWFTa_target_log)}')
# Out:
# RMSE Loss: 0.0008012686157599092

# %%
HWFTb_val_loss_epoch, HWFTb_target_log, HWFTb_pred_log = validate(best_model, HWFTb_test_loader, rmse, device=device)

plt.plot(HWFTb_pred_log.reshape(-1).cpu(), label='Predicted label')
plt.plot(HWFTb_target_log.reshape(-1).cpu(), label='True label')
plt.title('HWFTb Test Result')
plt.xlabel('Samples')
plt.ylabel('SOC (%)')
plt.legend()
print(f'RMSE Loss: {rmse(HWFTb_pred_log, HWFTb_target_log)}')
# Out:
# RMSE Loss: 0.0008234066772274673

# %%
eneroc_val_loss_epoch, eneroc_target_log, eneroc_pred_log = validate(best_model, eneroc_test_loader, rmse, device=device)

plt.plot(eneroc_pred_log.reshape(-1).cpu(), label='Predicted label')
plt.plot(eneroc_target_log.reshape(-1).cpu(), label='True label')
plt.title('ENEROC Test Result')
plt.xlabel('Samples')
plt.ylabel('SOC (%)')
plt.legend()
print(f'RMSE Loss: {rmse(eneroc_pred_log, eneroc_target_log)}')
# Out:
# RMSE Loss: 0.35797029733657837
