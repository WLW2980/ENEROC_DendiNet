# %%
import torch
import numpy as np
import pickle
import os
import sys
import matplotlib.pyplot as plt

from model.baseline.rnn import RNN
from utils.loss import rmse
from utils.F_train_validate import fit, validate
from configs.LSTM_GRU_configs import Configs

# return to main dir
current_directory = os.getcwd()
main_dir = os.path.dirname(current_directory+'/dataloader/')
sys.path.append(main_dir)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'avaiable device: {device}')
# Out:
# avaiable device: cuda

# %%
# random seed
seed = 77
torch.manual_seed(seed)
np.random.seed(seed)

if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
with open('dataloader/save/LSTM_GRU/train_loader.pkl', 'rb') as file:
    train_loader = pickle.load(file)
with open('dataloader/save/LSTM_GRU/val_loader.pkl', 'rb') as file:
    val_loader = pickle.load(file)
print('training and validation dataloaders are loaded!')
# Out:
# training and validation dataloaders are loaded!

# %%
lr = 5e-6
epochs = 30
patience = 5
model_save_dir = os.path.dirname(main_dir) + '/model_save/RNN.pth'

# %%
configs = Configs()
model = RNN(configs).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
train_loss, val_loss = fit(model, epochs, train_loader, val_loader,
                           optimizer, rmse, patience=patience,
                           model_save_dir=model_save_dir, device=device)
# Out:
# Epoch No.1 || Training loss: 0.135411 || Validation loss: 0.015052 || Time: 34.414 sec
# Epoch No.2 || Training loss: 0.015008 || Validation loss: 0.01037 || Time: 34.276 sec
# Epoch No.3 || Training loss: 0.012293 || Validation loss: 0.008225 || Time: 34.709 sec
# Epoch No.4 || Training loss: 0.011022 || Validation loss: 0.00657 || Time: 34.406 sec
# Epoch No.5 || Training loss: 0.010093 || Validation loss: 0.005977 || Time: 34.507 sec
# Epoch No.6 || Training loss: 0.009583 || Validation loss: 0.005364 || Time: 34.369 sec
# Epoch No.7 || Training loss: 0.009281 || Validation loss: 0.00461 || Time: 34.544 sec
# Epoch No.8 || Training loss: 0.008992 || Validation loss: 0.004625 || Time: 34.663 sec
# Epoch No.9 || Training loss: 0.008908 || Validation loss: 0.004059 || Time: 34.298 sec
# Epoch No.10 || Training loss: 0.008759 || Validation loss: 0.004613 || Time: 34.593 sec
# Epoch No.11 || Training loss: 0.008624 || Validation loss: 0.004747 || Time: 34.329 sec
# Epoch No.12 || Training loss: 0.008365 || Validation loss: 0.003295 || Time: 34.628 sec
# Epoch No.13 || Training loss: 0.008349 || Validation loss: 0.003411 || Time: 34.299 sec
# Epoch No.14 || Training loss: 0.008289 || Validation loss: 0.003459 || Time: 34.155 sec
# Epoch No.15 || Training loss: 0.008083 || Validation loss: 0.004581 || Time: 34.24 sec
# Epoch No.16 || Training loss: 0.008122 || Validation loss: 0.002748 || Time: 34.038 sec
# Epoch No.17 || Training loss: 0.008034 || Validation loss: 0.002916 || Time: 34.568 sec
# Epoch No.18 || Training loss: 0.008013 || Validation loss: 0.002677 || Time: 34.305 sec
# Epoch No.19 || Training loss: 0.008033 || Validation loss: 0.003063 || Time: 34.48 sec
# Epoch No.20 || Training loss: 0.008105 || Validation loss: 0.002722 || Time: 34.259 sec
# Epoch No.21 || Training loss: 0.008073 || Validation loss: 0.003521 || Time: 34.364 sec
# Epoch No.22 || Training loss: 0.008057 || Validation loss: 0.002629 || Time: 34.436 sec
# Epoch No.23 || Training loss: 0.008028 || Validation loss: 0.002441 || Time: 34.361 sec
# Epoch No.24 || Training loss: 0.007907 || Validation loss: 0.002421 || Time: 34.869 sec
# Epoch No.25 || Training loss: 0.007939 || Validation loss: 0.002857 || Time: 34.28 sec
# Epoch No.26 || Training loss: 0.007998 || Validation loss: 0.003731 || Time: 34.51 sec
# Epoch No.27 || Training loss: 0.007958 || Validation loss: 0.004114 || Time: 34.176 sec
# Epoch No.28 || Training loss: 0.007762 || Validation loss: 0.001945 || Time: 34.288 sec
# Epoch No.29 || Training loss: 0.008068 || Validation loss: 0.002052 || Time: 34.274 sec
# Epoch No.30 || Training loss: 0.007824 || Validation loss: 0.002185 || Time: 34.706 sec

# %%
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend()

# %%
with open('dataloader/save/LSTM_GRU/US06_test_loader.pkl', 'rb') as file:
    US06_test_loader = pickle.load(file)
with open('dataloader/save/LSTM_GRU/HWFTa_test_loader.pkl', 'rb') as file:
    HWFTa_test_loader = pickle.load(file)
with open('dataloader/save/LSTM_GRU/HWFTb_test_loader.pkl', 'rb') as file:
    HWFTb_test_loader = pickle.load(file)
with open('dataloader/save/LSTM_GRU/eneroc_test_loader.pkl', 'rb') as file:
    eneroc_test_loader = pickle.load(file)
print(f'Test dataloaders are loaded!')
# Out:
# Test dataloaders are loaded!

# %%
# load best model
best_model = RNN(configs).to(device)
best_model.load_state_dict(torch.load(model_save_dir))
# Out:
# <All keys matched successfully>

# %%
US06_val_loss_epoch, US06_target_log, US06_pred_log = validate(best_model, US06_test_loader, rmse, device=device)

plt.plot(US06_pred_log.reshape(-1).cpu(), label='Predicted label')
plt.plot(US06_target_log.reshape(-1).cpu(), label='True label')
plt.title('US06 Test Result')
plt.xlabel('Samples')
plt.ylabel('SOC (%)')
plt.legend()
print(f'RMSE Loss: {rmse(US06_pred_log, US06_target_log)}')
# Out:
# RMSE Loss: 0.003218826139345765

# %%
HWFTa_val_loss_epoch, HWFTa_target_log, HWFTa_pred_log = validate(best_model, HWFTa_test_loader, rmse, device=device)

plt.plot(HWFTa_pred_log.reshape(-1).cpu(), label='Predicted label')
plt.plot(HWFTa_target_log.reshape(-1).cpu(), label='True label')
plt.title('HWFTa Test Result')
plt.xlabel('Samples')
plt.ylabel('SOC (%)')
plt.legend()
print(f'RMSE Loss: {rmse(HWFTa_pred_log, HWFTa_target_log)}')
# Out:
# RMSE Loss: 0.0017691573593765497

# %%
HWFTb_val_loss_epoch, HWFTb_target_log, HWFTb_pred_log = validate(best_model, HWFTb_test_loader, rmse, device=device)

plt.plot(HWFTb_pred_log.reshape(-1).cpu(), label='Predicted label')
plt.plot(HWFTb_target_log.reshape(-1).cpu(), label='True label')
plt.title('HWFTb Test Result')
plt.xlabel('Samples')
plt.ylabel('SOC (%)')
plt.legend()
print(f'RMSE Loss: {rmse(HWFTb_pred_log, HWFTb_target_log)}')
# Out:
# RMSE Loss: 0.0017652242677286267

# %%
eneroc_val_loss_epoch, eneroc_target_log, eneroc_pred_log = validate(best_model, eneroc_test_loader, rmse, device=device)

plt.plot(eneroc_pred_log.reshape(-1).cpu(), label='Predicted label')
plt.plot(eneroc_target_log.reshape(-1).cpu(), label='True label')
plt.title('ENEROC Test Result')
plt.xlabel('Samples')
plt.ylabel('SOC (%)')
plt.legend()
print(f'RMSE Loss: {rmse(eneroc_pred_log, eneroc_target_log)}')
# Out:
# RMSE Loss: 0.6003983020782471
